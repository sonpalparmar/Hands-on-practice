# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
x = pd.array([0,6])
y = pd.array([100,200])
plt.plot(x,y)
plt.show()

# %%
x = [5,3,6,2,7,3,9,6]
y = [32,12,34,56,42,75,23,46]
plt.plot(x,y)
plt.show()

# %%
plt.scatter(x,y)

# %%
x = ['sonu','monu','akash','manish']
y = [98,89,88,78]
plt.bar(x,y)
plt.xlabel('Student')
plt.ylabel('Marks')
plt.title('Lovely professional university')
# Out:
# Text(0.5, 1.0, 'Lovely professional university')

# %%
a = np.random.rand(5,4)
a *=10
a = a.round(2)
y = np.array(range(20))
plt.scatter(y,a)

# %%
x = np.array([1, 2, 3, 4]) 
y = x*2
  
plt.plot(x, y) 
  
x1 = [2, 4, 6, 8] 
y1 = [3, 5, 7, 9] 
  
plt.plot(x, y1) 
plt.xlabel("X-axis data") 
plt.ylabel("Y-axis data") 
plt.title('multiple plots') 
  
plt.fill_between(x, y, y1, color='green', alpha=0.5) 
plt.show()

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('pizza.csv')
df
# Out:
#        pizza_id  order_id  pizza_name_id  quantity  order_date order_time  \
# 0             1         1     hawaiian_m         1  01-01-2015   11:38:36
# 1             2         2  classic_dlx_m         1  01-01-2015   11:57:40
# 2             3         2  five_cheese_l         1  01-01-2015   11:57:40
# 3             4         2    ital_supr_l         1  01-01-2015   11:57:40
# 4             5         2     mexicana_m         1  01-01-2015   11:57:40
# ...         ...       ...            ...       ...         ...        ...
# 48615     48616     21348  ckn_alfredo_m         1  31-12-2015   21:23:10
# 48616     48617     21348  four_cheese_l         1  31-12-2015   21:23:10
# 48617     48618     21348   napolitana_s         1  31-12-2015   21:23:10
# 48618     48619     21349     mexicana_l         1  31-12-2015   22:09:54
# 48619     48620     21350      bbq_ckn_s         1  31-12-2015   23:02:05
#
#        unit_price  total_price pizza_size pizza_category  \
# ...

# %%
df.isnull().sum()
# Out:
# pizza_id             0
# order_id             0
# pizza_name_id        0
# quantity             0
# order_date           0
# order_time           0
# unit_price           0
# total_price          0
# pizza_size           0
# pizza_category       0
# pizza_ingredients    0
# pizza_name           0
# dtype: int64

# %%
plt.plot(df['order_date'].head(500),df['total_price'].head(500),'o',c='red')

# %%
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(2,1,1)
plt.plot(x,y)

y1 = np.array([10,20,30,40])
plt.subplot(2,1,2)
plt.plot(x,y1)

# %%
y = np.
